# %% [markdown]
# <a href="https://colab.research.google.com/github/JOSSORMORA26/PRACTICA/blob/master/Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("¡Hola mundo!")
# Out:
# ¡Hola mundo!

# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = 'indian-candidates-for-general-election-2019.zip'
df = pd.read_csv(path, encoding='latin', error_bad_lines=False)
df.head()
# Out:
#            STATE  ... TOTAL ELECTORS
# 0      Telangana  ...        1489790
# 1      Telangana  ...        1489790
# 2      Telangana  ...        1489790
# 3      Telangana  ...        1489790
# 4  Uttar Pradesh  ...        1937690
#
# [5 rows x 19 columns]

# %%
df.loc[30:80]
# Out:
#              STATE  ... TOTAL ELECTORS
# 30          Kerala  ...        1266794
# 31          Kerala  ...        1266794
# 32   Uttar Pradesh  ...        1887127
# 33   Uttar Pradesh  ...        1887127
# 34   Uttar Pradesh  ...        1887127
# 35     West Bengal  ...        1648383
# 36     West Bengal  ...        1648383
# 37     West Bengal  ...        1648383
# 38     West Bengal  ...        1648383
# 39     West Bengal  ...        1648383
# 40   Uttar Pradesh  ...        1716160
# 41   Uttar Pradesh  ...        1716160
# 42   Uttar Pradesh  ...        1716160
# 43   Uttar Pradesh  ...        1716160
# 44     Uttarakhand  ...        1337808
# 45     Uttarakhand  ...        1337808
# 46     Uttarakhand  ...        1337808
# 47     Uttarakhand  ...        1337808
# 48       Rajasthan  ...        1888524
# 49       Rajasthan  ...        1888524
# 50       Rajasthan  ...        1888524
# 51  Andhra Pradesh  ...        1459556
# 52  Andhra Pradesh  ...        1459556
# ...

# %%
df.drop([0,2,13], axis=0).head()
# Out:
#            STATE  ... TOTAL ELECTORS
# 1      Telangana  ...        1489790
# 3      Telangana  ...        1489790
# 4  Uttar Pradesh  ...        1937690
# 5  Uttar Pradesh  ...        1937690
# 6  Uttar Pradesh  ...        1937690
#
# [5 rows x 19 columns]

# %%
df[20:].head() #df.tail(-20) )
# Out:
#             STATE  ... TOTAL ELECTORS
# 20  Uttar Pradesh  ...        1766121
# 21  Uttar Pradesh  ...        1766121
# 22  Uttar Pradesh  ...        1766121
# 23    Maharashtra  ...        1865169
# 24    Maharashtra  ...        1865169
#
# [5 rows x 19 columns]

# %%
df.STATE.unique()
# Out:
# array(['Telangana', 'Uttar Pradesh', 'Maharashtra', 'Gujarat',
#        'Rajasthan', 'Kerala', 'West Bengal', 'Uttarakhand',
#        'Andhra Pradesh', 'Haryana', 'Punjab', 'Jammu & Kashmir',
#        'Andaman & Nicobar Islands', 'Tamil Nadu', 'Bihar',
#        'Arunachal Pradesh', 'Odisha', 'Assam', 'Karnataka',
#        'Madhya Pradesh', 'Chhattisgarh', 'Chandigarh', 'NCT OF Delhi',
#        'Jharkhand', 'Dadra & Nagar Haveli', 'Daman & Diu',
#        'Himachal Pradesh', 'Manipur', 'Lakshadweep', 'Mizoram',
#        'Nagaland', 'Goa', 'Puducherry', 'Meghalaya', 'Sikkim', 'Tripura'],
#       dtype=object)

# %%
df.EDUCATION.value_counts()
# Out:
# Post Graduate            502
# Graduate                 441
# Graduate Professional    336
# 12th Pass                256
# 10th Pass                196
# 8th Pass                  78
# Doctorate                 73
# Others                    50
# Literate                  30
# 5th Pass                  28
# Not Available             22
# Illiterate                 5
# Post Graduate\n            1
# Name: EDUCATION, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          STATE  ...  TOTAL ELECTORS
# count     2263  ...            2263
# size      2263  ...            2263
# nunique     36  ...             542
#
# [3 rows x 19 columns]

# %%
df.groupby('STATE').agg(['count', 'size', 'nunique']).stack()
# Out:
#                                    CONSTITUENCY  ...  TOTAL ELECTORS
# STATE                                            ...
# Andaman & Nicobar Islands count               5  ...               5
#                           size                5  ...               5
#                           nunique             1  ...               1
# Andhra Pradesh            count             121  ...             121
#                           size              121  ...             121
# ...                                         ...  ...             ...
# Uttarakhand               size               16  ...              16
#                           nunique             5  ...               5
# West Bengal               count             193  ...             193
#                           size              193  ...             193
#                           nunique            42  ...              42
#
# [108 rows x 18 columns]

# %%
df.AGE.value_counts()
# Out:
# 55.0    67
# 52.0    66
# 58.0    63
# 48.0    62
# 46.0    62
# 61.0    61
# 44.0    60
# 59.0    60
# 43.0    59
# 56.0    57
# 64.0    57
# 49.0    56
# 50.0    55
# 42.0    55
# 54.0    55
# 51.0    53
# 60.0    52
# 62.0    52
# 65.0    51
# 47.0    51
# 68.0    48
# 53.0    48
# 57.0    48
# 67.0    44
# 63.0    44
# 45.0    44
# 41.0    42
# 66.0    40
# 38.0    37
# 40.0    36
# 37.0    35
# 36.0    32
# 39.0    32
# 33.0    29
# 69.0    28
# 70.0    25
# 32.0    23
# 71.0    22
# 35.0    20
# 31.0    20
# 34.0    17
# 72.0    15
# 30.0    15
# 28.0    14
# 29.0    13
# 73.0    13
# 74.0    11
# 27.0    10
# 26.0    10
# 78.0    10
# 77.0     8
# 75.0     7
# 76.0     6
# 25.0     6
# 79.0     4
# 81.0     2
# 82.0     2
# 86.0     2
# 80.0     1
# 83.0     1
# Name: AGE, dtype: int64

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#                 STATE  ... TOTAL ELECTORS
# 1889   Madhya Pradesh  ...        1575064
# 282   Jammu & Kashmir  ...        1317738
# 1454      Maharashtra  ...        1588693
# 1980            Bihar  ...        1799551
# 2080           Kerala  ...        1371427
#
# [5 rows x 19 columns]

# %%
df_dropped = df.dropna(subset=['STATE'])
df_dropped.head()
# Out:
#            STATE  ... TOTAL ELECTORS
# 0      Telangana  ...        1489790
# 1      Telangana  ...        1489790
# 2      Telangana  ...        1489790
# 3      Telangana  ...        1489790
# 4  Uttar Pradesh  ...        1937690
#
# [5 rows x 19 columns]

# %%
df_dropped.shape
# Out:
# (2263, 19)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#            STATE  ... TOTAL ELECTORS
# 0      Telangana  ...        1489790
# 1      Telangana  ...        1489790
# 2      Telangana  ...        1489790
# 3      Telangana  ...        1489790
# 4  Uttar Pradesh  ...        1937690
#
# [5 rows x 19 columns]

# %%
df_copy.shape
# Out:
# (2263, 19)

# %%
df_dropped['AGE'].dtype
# Out:
# dtype('float64')

# %%
df_copy['AGE'].fillna(value=np.round(df['AGE'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          STATE  ...  TOTAL ELECTORS
# count     2263  ...            2263
# size      2263  ...            2263
# nunique     36  ...             542
#
# [3 rows x 19 columns]

# %%
list(df['WINNER'].unique())
# Out:
# [1, 0]

# %%
"""
1 Ganadores
0 Perdedores
"""
df['WINNER'].replace({1:"ganador", 
                       0:"perdedor"}, inplace=True)

# %%
list(df['WINNER'].unique())
# Out:
# ['ganador', 'perdedor']

# %%
keys = list(df['WINNER'].unique())
vals = range(-1,2)
act = dict(zip(keys, vals))
act
# Out:
# {'ganador': -1, 'perdedor': 0}

# %%
df_copy['WINNER_NVO'] = df['WINNER'].map(act)
df_copy.head()
# Out:
#            STATE CONSTITUENCY  ... TOTAL ELECTORS  WINNER_NVO
# 0      Telangana     ADILABAD  ...        1489790          -1
# 1      Telangana     ADILABAD  ...        1489790           0
# 2      Telangana     ADILABAD  ...        1489790           0
# 3      Telangana     ADILABAD  ...        1489790           0
# 4  Uttar Pradesh         AGRA  ...        1937690          -1
#
# [5 rows x 20 columns]

# %%
list(df_copy['WINNER_NVO'].unique())
# Out:
# [-1, 0]

# %%
df_copy['AGE'].mean()
# Out:
# 52.243923994697305

# %%
df_copy['AGE'][df_copy['WINNER'] == 1]
# Out:
# 0       52.0
# 4       58.0
# 7       37.0
# 10      58.0
# 12      69.0
#         ...
# 2243    65.0
# 2247    48.0
# 2250    41.0
# 2253    46.0
# 2259    63.0
# Name: AGE, Length: 539, dtype: float64

# %%
df_copy['AGE'][df_copy['WINNER_NVO'] == -1].mean()
# Out:
# 54.44155844155844

# %%
df_copy.groupby(["WINNER_NVO", "STATE", "CONSTITUENCY", "PARTY"]).count()
# Out:
#                                                                        NAME  ...  TOTAL ELECTORS
# WINNER_NVO STATE                     CONSTITUENCY              PARTY         ...
# -1         Andaman & Nicobar Islands ANDAMAN & NICOBAR ISLANDS INC        1  ...               1
#            Andhra Pradesh            AMALAPURAM                YSRCP      1  ...               1
#                                      ANAKAPALLI                YSRCP      1  ...               1
#                                      ANANTAPUR                 YSRCP      1  ...               1
#                                      ARUKU                     YSRCP      1  ...               1
# ...                                                                     ...  ...             ...
#  0         West Bengal               TAMLUK                    CPI(M)     1  ...               1
#                                                                INC        1  ...               1
# ...

# %%
df_copy.groupby(["WINNER_NVO", "STATE"])[["CONSTITUENCY", "PARTY"]].count()
# Out:
#                                       CONSTITUENCY  PARTY
# WINNER_NVO STATE
# -1         Andaman & Nicobar Islands             1      1
#            Andhra Pradesh                       25     25
#            Arunachal Pradesh                     2      2
#            Assam                                14     14
#            Bihar                                41     41
# ...                                            ...    ...
#  0         Telangana                            66     66
#            Tripura                               8      8
#            Uttar Pradesh                       196    196
#            Uttarakhand                          11     11
#            West Bengal                         151    151
#
# [72 rows x 2 columns]

# %%
df_copy.WINNER_NVO
# Out:
# 0      -1
# 1       0
# 2       0
# 3       0
# 4      -1
#        ..
# 2258    0
# 2259   -1
# 2260    0
# 2261    0
# 2262    0
# Name: WINNER_NVO, Length: 2263, dtype: int64

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#                 STATE  ... TOTAL ELECTORS
# 1889   Madhya Pradesh  ...        1575064
# 282   Jammu & Kashmir  ...        1317738
# 1454      Maharashtra  ...        1588693
# 1980            Bihar  ...        1799551
# 2080           Kerala  ...        1371427
#
# [5 rows x 19 columns]

# %%
df_sample.groupby(["WINNER", "STATE"])[["AGE", "TOTAL\nVOTES"]].agg([np.sum, np.mean,
                                                              np.count_nonzero])
# Out:
#                                       AGE  ...  TOTAL\nVOTES
#                                       sum  ... count_nonzero
# WINNER   STATE                             ...
# ganador  Bihar                       61.0  ...             1
#          Gujarat                     69.0  ...             1
#          Jharkhand                   52.0  ...             1
#          Kerala                      56.0  ...             1
#          Maharashtra                122.0  ...             3
#          NCT OF Delhi                64.0  ...             1
#          Odisha                      47.0  ...             1
#          Punjab                      45.0  ...             1
#          Rajasthan                   51.0  ...             1
#          Tamil Nadu                  49.0  ...             1
#          Uttar Pradesh              417.0  ...             7
#          West Bengal                 36.0  ...             1
# perdedor Andaman & Nicobar Islands  110.0  ...             2
# ...

# %%
df_sample.groupby(["WINNER", "STATE"]).agg({'GENERAL\nVOTES':np.mean,'TOTAL\nVOTES':np.max})
# Out:
#                                     GENERAL\nVOTES  TOTAL\nVOTES
# WINNER   STATE
# ganador  Bihar                       562424.000000        568150
#          Gujarat                     770442.000000        771980
#          Jharkhand                   369527.000000        371595
#          Kerala                      437997.000000        440415
#          Maharashtra                 615041.333333        749085
#          NCT OF Delhi                517939.000000        519055
#          Odisha                      471382.000000        473770
#          Punjab                      412201.000000        413561
#          Rajasthan                   781166.000000        788888
#          Tamil Nadu                  444152.000000        447075
#          Uttar Pradesh               591554.142857        726349
#          West Bengal                 717407.000000        717959
# perdedor Andaman & Nicobar Islands     4088.000000          5341
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
fig

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
df.AGE.replace(np.NaN,0)
# Out:
# 0       52.0
# 1       54.0
# 2       52.0
# 3        0.0
# 4       58.0
#         ...
# 2258    43.0
# 2259    63.0
# 2260    49.0
# 2261    47.0
# 2262     0.0
# Name: AGE, Length: 2263, dtype: float64

# %%
df_sample['TOTAL\nVOTES'] = df_sample['TOTAL\nVOTES'].astype('int64')

df_sample.plot(kind='scatter',x='TOTAL\nVOTES',y='AGE')

# %%
plt.hist(df_sample['WINNER'])
plt.xlabel('WINNER')
plt.ylabel('Frequency')
plt.title('Frequency of tipoact')
# Out:
# Text(0.5, 1.0, 'Frequency of tipoact')

# %%
plt.hist(df_sample['TOTAL\nVOTES'])
plt.xlabel('TOTAL\nVOTES')
plt.ylabel('Frequency')
plt.title('Frequency of ventas')
# Out:
# Text(0.5, 1.0, 'Frequency of ventas')

# %%
plt.boxplot(df_sample['TOTAL\nVOTES'], showmeans=True, meanline=True)
plt.ylabel('TOTAL VOTOS')
plt.title('Box Plot of Total Votos')
# Out:
# Text(0.5, 1.0, 'Box Plot of Total Votos')
